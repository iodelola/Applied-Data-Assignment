# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px


# reading all csv's
df_access_electricity = pd.read_csv("Access_electricity.csv")
df_Electri_consumption= pd.read_csv("Electric_power_consumption.csv")

# %%
df_access_electricity.head()
# Out:
#                   Country Name       2000        2001        2002        2003  \
# 0                        Aruba  91.660398  100.000000  100.000000  100.000000
# 1  Africa Eastern and Southern  20.086007   23.103178   24.223430   25.023184
# 2                  Afghanistan        NaN         NaN         NaN         NaN
# 3   Africa Western and Central  34.658011   35.664311   36.403550   40.673975
# 4                       Angola        NaN   20.000000   26.383869   27.465635
#
#          2004        2005        2006        2007        2008        2009  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   26.176336   23.621498   27.299433   28.737952   28.813735   27.483061
# 2         NaN   22.295269   28.099962   33.901604   42.400000   45.520683
# 3   37.757913   38.007909   39.860706   40.744232   41.686699   41.865713
# 4   28.536760   29.596224   30.646555   37.500000   38.490000   33.804184
#
# ...

# %%
# add columns with Elements
df_access_electricity["Element"] = "Access to Electricity"
df_Electri_consumption["Element"] = "Electric Power consumption"


df_Electri_consumption.head()
# Out:
#                   Country Name        2000        2001        2002  \
# 0                        Aruba         NaN         NaN         NaN
# 1  Africa Eastern and Southern  780.702624  743.916044  769.080854
# 2                  Afghanistan         NaN         NaN         NaN
# 3   Africa Western and Central  116.708798  119.051133  133.754417
# 4                       Angola   75.264660   82.616571   86.018839
#
#          2003        2004        2005        2006        2007        2008  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1  774.334166  777.672091  780.851052  789.487840  796.901936  760.576897
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3  123.896644  138.893764  145.325051  144.984987  158.419738  154.500732
# 4   95.853114   87.535341  109.295219  144.715323  133.267258  172.384898
#
#          2009        2010        2011        2012        2013        2014  \
# ...

# %%
# merge both csv files. 
df_climate_change = pd.concat([df_access_electricity, df_Electri_consumption])
df_climate_change.head()
# Out:
#                   Country Name       2000        2001        2002        2003  \
# 0                        Aruba  91.660398  100.000000  100.000000  100.000000
# 1  Africa Eastern and Southern  20.086007   23.103178   24.223430   25.023184
# 2                  Afghanistan        NaN         NaN         NaN         NaN
# 3   Africa Western and Central  34.658011   35.664311   36.403550   40.673975
# 4                       Angola        NaN   20.000000   26.383869   27.465635
#
#          2004        2005        2006        2007        2008        2009  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   26.176336   23.621498   27.299433   28.737952   28.813735   27.483061
# 2         NaN   22.295269   28.099962   33.901604   42.400000   45.520683
# 3   37.757913   38.007909   39.860706   40.744232   41.686699   41.865713
# 4   28.536760   29.596224   30.646555   37.500000   38.490000   33.804184
#
# ...

# %%
# sort and save as csv file
df_climate_change = df_climate_change.sort_values(["Country Name"])
df_climate_change.to_csv("climate_change_info.csv")

# %%
# statistical overview
df_climate_change.describe()
# Out:
#                2000          2001          2002          2003          2004  \
# count    422.000000    428.000000    434.000000    434.000000    436.000000
# mean    1480.524976   1480.813536   1489.307313   1521.061970   1541.737360
# std     3337.203076   3357.799659   3381.002345   3396.738868   3428.472199
# min        2.439689      1.270180      3.154657      3.498533      3.500000
# 25%       84.783556     85.475630     86.689940     87.263508     87.401433
# 50%      100.000000    100.000000    100.000000    100.000000    100.000000
# 75%     1283.836326   1247.828003   1243.679993   1332.044814   1419.465160
# max    26201.525580  26950.394430  27896.898680  27666.386890  28215.452250
#
#                2005          2006          2007          2008          2009  \
# count    440.000000    442.000000    442.000000    444.000000    447.000000
# mean    1568.659479   1597.309412   1627.076141   1646.444360   1591.692428
# ...

# %%
# Line charts of dataset, Access to electricity and Electric power consumption of the whole world
df_elements = df_climate_change.groupby("Element").sum()
df_elements
# Out:
#                                      2000           2001           2002  \
# Element
# Access to Electricity        18127.917298   18507.260918   19071.873051
# Electric Power consumption  606653.622744  615280.932603  627287.500851
#
#                                      2003           2004           2005  \
# Element
# Access to Electricity        19229.719921   19455.662702   19638.779597
# Electric Power consumption  640911.175206  652741.826305  670571.391262
#
#                                      2006           2007           2008  \
# Element
# Access to Electricity        20016.460992   20099.716469   20395.125649
# Electric Power consumption  685994.299043  699067.937694  710626.170193
#
#                                      2009           2010           2011  \
# Element
# Access to Electricity        20591.616285   20852.830674   21080.529105
# Electric Power consumption  690894.898843  720013.196468  720301.652830
#
# ...

# %%
#Transpose the dataframe
elements_t = df_elements.T
elements_t.head()
# Out:
# Element  Access to Electricity  Electric Power consumption
# 2000              18127.917298               606653.622744
# 2001              18507.260918               615280.932603
# 2002              19071.873051               627287.500851
# 2003              19229.719921               640911.175206
# 2004              19455.662702               652741.826305

# %%
plt.scatter(elements_t['Access to Electricity'], elements_t['Electric Power consumption'])

# %%
#Pot a line chat for the Indicator
sns.set_style("darkgrid")
line = sns.lineplot(x=elements_t.index, 
                    y=elements_t['Access to Electricity'], 
                    data=elements_t, color="red", marker='o')
plt.xticks(rotation=45)
figsize=(18, 8)
plt.tight_layout()

# %%
#line plot
sns.set_style("darkgrid")
line = sns.lineplot(x=elements_t.index, 
                    y=elements_t['Electric Power consumption'], 
                    data=elements_t, color="blue", marker='+')
plt.xticks(rotation=45)
figsize=(50, 8)
plt.tight_layout()

# %%
# correlation matrices
df_climate_change.corr()
# Out:
#           2000      2001      2002      2003      2004      2005      2006  \
# 2000  1.000000  0.999592  0.999110  0.997644  0.997242  0.997352  0.994571
# 2001  0.999592  1.000000  0.999584  0.998076  0.997907  0.997897  0.995639
# 2002  0.999110  0.999584  1.000000  0.999161  0.998957  0.998504  0.997061
# 2003  0.997644  0.998076  0.999161  1.000000  0.999663  0.998992  0.998028
# 2004  0.997242  0.997907  0.998957  0.999663  1.000000  0.999075  0.998281
# 2005  0.997352  0.997897  0.998504  0.998992  0.999075  1.000000  0.998658
# 2006  0.994571  0.995639  0.997061  0.998028  0.998281  0.998658  1.000000
# 2007  0.989160  0.990685  0.992495  0.992857  0.993769  0.993540  0.997400
# 2008  0.960285  0.962874  0.965973  0.965528  0.967403  0.965685  0.975296
# 2009  0.949519  0.952490  0.955975  0.955502  0.957641  0.955531  0.966373
# 2010  0.953971  0.956886  0.960248  0.959915  0.962141  0.959994  0.970586
# ...

# %%
#Diplay an Heatmap ,graphical representation of data where values are depicted by color.
f,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df_climate_change.corr(), annot=True, linewidths=.8, fmt= '.1f',ax=ax)
# Out:
# <AxesSubplot:>

# %%
#correlation table 
df_climate_change.corr(method="kendall")
# Out:
#           2000      2001      2002      2003      2004      2005      2006  \
# 2000  1.000000  0.980615  0.969192  0.966757  0.962791  0.952505  0.940545
# 2001  0.980615  1.000000  0.979694  0.975228  0.971655  0.960908  0.948918
# 2002  0.969192  0.979694  1.000000  0.980958  0.980484  0.968379  0.956127
# 2003  0.966757  0.975228  0.980958  1.000000  0.986368  0.976005  0.962699
# 2004  0.962791  0.971655  0.980484  0.986368  1.000000  0.980420  0.963901
# 2005  0.952505  0.960908  0.968379  0.976005  0.980420  1.000000  0.966265
# 2006  0.940545  0.948918  0.956127  0.962699  0.963901  0.966265  1.000000
# 2007  0.936850  0.945647  0.953774  0.959272  0.961280  0.964482  0.976572
# 2008  0.932199  0.939151  0.947684  0.954091  0.957873  0.959939  0.974566
# 2009  0.927703  0.933935  0.941564  0.949127  0.951803  0.953362  0.965416
# 2010  0.917639  0.921490  0.928457  0.936134  0.937581  0.943532  0.951834
# ...

# %%
#save excel files
df_climate_change.to_excel("pearson.xlsx")
df_climate_change.to_excel("kendall.xlsx")

# %%
#plot a pairplot 
fig= sns.pairplot(elements_t)
fig.tight_layout()
plt.savefig('output.png', dpi=300)

# %%
# get number of nan by column
df_climate_change.isna().sum()
# Out:
# Country Name      0
# 2000            110
# 2001            104
# 2002             98
# 2003             98
# 2004             96
# 2005             92
# 2006             90
# 2007             90
# 2008             88
# 2009             85
# 2010             84
# 2011             83
# 2012             82
# 2013             82
# 2014             82
# Element           0
# dtype: int64

# %%
#Drop all NA's colunms
df_clean = df_climate_change.dropna()
df_clean.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bff1da5646a1> in <module>
#       1 #Drop all NA's colunms
# ----> 2 df_clean = df_climate_change.dropna()
#       3 df_clean.describe()
#
# NameError: name 'df_climate_change' is not defined
